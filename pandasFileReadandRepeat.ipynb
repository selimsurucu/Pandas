# %% [markdown]
# <a href="https://colab.research.google.com/github/selimsurucu/Pandas/blob/master/pandasFileReadandRepeat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas'ı import ediyoruz.

# %%
import pandas as pd

# %% [markdown]
# Bir csv dosyası okuyacağız . Airbnb den istanbul datasını aldık ve bunu okuyacağımız için önce dosyamızı colab a yüklüyoruz.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8f65d8b6-a567-4587-9e7a-07d876927f72" name="files[]" multiple disabled />
#      <output id="result-8f65d8b6-a567-4587-9e7a-07d876927f72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving istanbul.csv to istanbul.csv

# %% [markdown]
# Dosyamızı dataframe olarak yüklüyoruz

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['istanbul.csv']))

# %% [markdown]
# istanbul.csv dosyasındaki kolonları yazdıralım.

# %%
print(df2.columns)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        ...
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object', length=106)

# %% [markdown]
# Dataframemize ait genel bilgileri alalım.

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16251 entries, 0 to 16250
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(25), int64(21), object(60)
# memory usage: 13.1+ MB
# None

# %% [markdown]
# istanbul.csv dosyamızdaki property_type özelliği yazdıralım. (apartment,house vs.)

# %%
print(df2.property_type)
# Out:
# 0                 Apartment
# 1                 Apartment
# 2        Serviced apartment
# 3                 Apartment
# 4                 Apartment
# 5                 Apartment
# 6                 Apartment
# 7                 Apartment
# 8                 Apartment
# 9                 Apartment
# 10                Apartment
# 11                    Villa
# 12                Apartment
# 13                Apartment
# 14                    House
# 15                Apartment
# 16                Apartment
# 17                Apartment
# 18                Apartment
# 19                Apartment
# 20                Apartment
# 21                Apartment
# 22                Apartment
# 23                Apartment
# 24                Apartment
# 25                Apartment
# 26                Apartment
# 27                Apartment
# 28                Apartment
# 29                Apartment
#                 ...
# 16221             Apartment
# 16222                 House
# ...

# %% [markdown]
# property_type özelliğini yazdırdığımızda aynı kayıtlardan geldiğini görüyoruz. eğer aynı kayıtların gelmemesini istiyorsak

# %%
print(df2.property_type.unique())
# Out:
# ['Apartment' 'Serviced apartment' 'Villa' 'House' 'Bed and breakfast'
#  'Boutique hotel' 'Loft' 'Boat' 'Condominium' 'Townhouse' 'Chalet'
#  'Aparthotel' 'Other' 'Guesthouse' 'Hostel' 'Guest suite' 'Earth house'
#  'Camper/RV' 'Nature lodge' 'Hotel' 'Casa particular (Cuba)' 'Cottage'
#  'Yurt' 'Treehouse' 'Bungalow' 'Farm stay' 'Tent' 'Lighthouse' 'Hut'
#  'Dome house' 'Cabin' 'Minsu (Taiwan)' 'In-law' 'Tiny house' 'Castle'
#  'Pousada' 'Cave' 'Campsite']

# %% [markdown]
# istanbul.csv de ki Apartment ve Treehouse olanları ayrı ayrı frame atayalım

# %%
apartmentDf = df2[df2.property_type=="Apartment"]
treeHouseDf = df2[df2.property_type == "Treehouse"]

# %% [markdown]
# Yeni oluşturduğumuz dataframeleri yazdıralım.

# %%
print("Apartment")
print(apartmentDf)
print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
print("Treehouse")
print(treeHouseDf)
# Out:
# Apartment
#              id                            listing_url       scrape_id  \
# 0          4826      https://www.airbnb.com/rooms/4826  20190218135301
# 1         20815     https://www.airbnb.com/rooms/20815  20190218135301
# 3         27271     https://www.airbnb.com/rooms/27271  20190218135301
# 4         28277     https://www.airbnb.com/rooms/28277  20190218135301
# 5         28308     https://www.airbnb.com/rooms/28308  20190218135301
# 6         28318     https://www.airbnb.com/rooms/28318  20190218135301
# 7         29241     https://www.airbnb.com/rooms/29241  20190218135301
# 8         30697     https://www.airbnb.com/rooms/30697  20190218135301
# 9         33368     https://www.airbnb.com/rooms/33368  20190218135301
# 10        33580     https://www.airbnb.com/rooms/33580  20190218135301
# 12        34177     https://www.airbnb.com/rooms/34177  20190218135301
# 13        34925     https://www.airbnb.com/rooms/34925  20190218135301
# ...

# %% [markdown]
# treeHouseDf dataframemizde ücret bilgilerini yazdıralım.

# %%
print(treeHouseDf.price)
# Out:
# 3592     $200.00
# 6178     $179.00
# 7774     $527.00
# 11468     $69.00
# 11870     $79.00
# Name: price, dtype: object
